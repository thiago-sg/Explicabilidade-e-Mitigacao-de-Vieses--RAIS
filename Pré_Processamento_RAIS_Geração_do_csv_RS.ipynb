# %%
import pandas as pd

# %%
# O arquivo tem 5,6gb e 12284031 linhas, com a linha 1 sendo o cabeçalho, conforme visto no glogg
# Tentar verificar em duas partes

# %%
df_rais_2019_sul_1 = pd.read_csv('RAIS_VINC_PUB_SUL.txt',
                                 sep=';', encoding='latin', nrows=6000000)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_rais_2019_sul_1.head()
# Out:
#              Bairros SP  ... Ind Trab Parcial
# 0             {ñ class}  ...                0
# 1             {ñ class}  ...                0
# 2             {ñ class}  ...                0
# 3             {ñ class}  ...                0
# 4             {ñ class}  ...                0
#
# [5 rows x 60 columns]

# %%
df_rais_2019_sul_1.shape
# Out:
# (6000000, 60)

# %%
# Considerando apenas trabalhadores de empresas do RS (código 43 no IBGE)

df_rais_2019_sul_1['Município'] = df_rais_2019_sul_1['Município'].astype(str)

# %%
df_rais_2019_sul_1['Município'].value_counts()[:20]
# Out:
# 410690    1336366
# 411370     248730
# 411520     242814
# 410480     167344
# 420540     166169
# 412550     142249
# 411990     132726
# 420910     125990
# 410830      97817
# 420240      80090
# 412770      75985
# 421660      69288
# 410180      63005
# 410940      62714
# 411915      62612
# 410580      57149
# 420820      56657
# 411820      54542
# 420420      53318
# 410150      49652
# Name: Município, dtype: int64

# %%
df_rais_2019_RS_1 = df_rais_2019_sul_1[df_rais_2019_sul_1['Município'].str.startswith('43')]

# %%
# Não existe empresa do RS nessa primeira parte do arquivo

df_rais_2019_RS_1.shape
# Out:
# (0, 60)

# %%
# Carregando segunda parte

df_rais_2019_sul_2 = pd.read_csv('/content/drive/MyDrive/TC - Data Science/Linguagem ofensiva - Fairness e Bias/RAIS CAGED/RAIS_VINC_PUB_SUL.txt',
                               sep=';', encoding='latin', skiprows=range(1, 6000000))
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_rais_2019_sul_2.head()
# Out:
#              Bairros SP  ... Ind Trab Parcial
# 0             {ñ class}  ...                0
# 1             {ñ class}  ...                0
# 2             {ñ class}  ...                0
# 3             {ñ class}  ...                0
# 4             {ñ class}  ...                0
#
# [5 rows x 60 columns]

# %%
df_rais_2019_sul_2.shape
# Out:
# (6284031, 60)

# %%
df_rais_2019_sul_2['Município'] = df_rais_2019_sul_2['Município'].astype(str)

# %%
df_rais_2019_RS = df_rais_2019_sul_2[df_rais_2019_sul_2['Município'].str.startswith('43')]

# %%
df_rais_2019_RS.head()
# Out:
#                    Bairros SP  ... Ind Trab Parcial
# 2094570             {ñ class}  ...                0
# 2094571             {ñ class}  ...                0
# 2094572             {ñ class}  ...                0
# 2094573             {ñ class}  ...                0
# 2094574             {ñ class}  ...                0
#
# [5 rows x 60 columns]

# %%
df_rais_2019_RS.shape
# Out:
# (4189461, 60)

# %%
df_rais_2019_RS.to_csv('df_rais_2019_RS.csv', index=False)

# %%
df_rais_2019_RS['Município'].value_counts()
# Out:
# 431490    955559
# 430510    229767
# 430460    119758
# 431340    103920
# 431440    100457
#            ...
# 431075       211
# 432218       201
# 431507       185
# 430593       159
# 430583       150
# Name: Município, Length: 497, dtype: int64
